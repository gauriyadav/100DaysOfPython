# %%
logo = """ 
 _      _____ _     ____  ____  _      _____    
/ \  /|/  __// \   /   _\/  _ \/ \__/|/  __/    
| |  |||  \  | |   |  /  | / \|| |\/|||  \      
| |/\|||  /_ | |_/\|  \_ | \_/|| |  |||  /_     
\_/  \|\____\\____/\____/\____/\_/  \|\____\    
                                                
""" 
print(logo)
from random import randint
EASY_LEVEL_TURNS = 10
HARD_LEVEL_TURNS = 5


def check_answer(guess,answer,turns):
  
  if guess > answer:
    print("Too high")
    return turns-1
  elif guess < answer:
    print("Too low")
    return turns-1
  else:
    print(f"You got it! The answer was {answer}.")

def set_difficulty():
  level = input("Choose the difficulty level. Type 'hard' or 'easy':  ") 
  if level == "easy":
    
    return EASY_LEVEL_TURNS
  else:
    return HARD_LEVEL_TURNS



def game():
  print("WELCOME TO THE GUESSING NUMBER!")
  print("I am thinking of a number between 1 and 100")
  answer =  randint(1,100)
  print(f"The answer is {answer}")

  turns = set_difficulty()

  
  guess=0
  while guess!= answer: 
    print(f"You have {turns} attempts remaining to guess the number.")
    guess = int(input("Make a guess:  "))
    turns = check_answer(guess,answer,turns)
    if turns == 0:
      print("You've run out of the guess.You lose")
      return
    elif guess!= answer:
      print("Guess again.")
game()
# Out:
#
#  _      _____ _     ____  ____  _      _____
# / \  /|/  __// \   /   _\/  _ \/ \__/|/  __/
# | |  |||  \  | |   |  /  | / \|| |\/|||  \
# | |/\|||  /_ | |_/\|  \_ | \_/|| |  |||  /_
# \_/  \|\____\____/\____/\____/\_/  \|\____\
#
#
# WELCOME TO THE GUESSING NUMBER!
# I am thinking of a number between 1 and 100
# The answer is 1
# Choose the difficulty level. Type 'hard' or 'easy':  hard
# You have 5 attempts remaining to guess the number.
# Make a guess:  50
# Too high
# Guess again.
# You have 4 attempts remaining to guess the number.
# Make a guess:  3
# Too high
# Guess again.
# You have 3 attempts remaining to guess the number.
# Make a guess:  1
# You got it! The answer was 1.
